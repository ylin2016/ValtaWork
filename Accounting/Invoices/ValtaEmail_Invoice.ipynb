# %%
import re
from pathlib import Path
from dateutil.parser import parse as parse_date
import pdfplumber
from datetime import date
import pandas as pd
import numpy as np
def extract_total(text: str):
    """Extract Total or Grand Total."""
    m = re.search(r"Grand Total\s*\$([\d,\.]+)", text, flags=re.IGNORECASE)
    if not m:
        matches = re.findall(r"Total\s*\$([\d,\.]+)", text, flags=re.IGNORECASE)
        if not matches:
            return None
        amount_str = matches[-1]
    else:
        amount_str = m.group(1)
    return float(amount_str.replace(",", ""))


def extract_service_date(text: str):
    """Extract date from 'Date: Dec 5, 2025'."""
    m = re.search(r"Date\s*:\s*(.+)", text, flags=re.IGNORECASE)
    if not m:
        return None
    try:
        return parse_date(m.group(1)).date().isoformat()
    except:
        return None


def extract_listing(text: str):
    """
    Extract listing/property name from item line:
    '01 593 Poulsbo  $150.00'
    """
    m = re.search(r"^\s*\d+\s+(.+?)\s+\$\s*[\d,\.]+", text, flags=re.MULTILINE)
    if not m:
        return None
    
    listing = m.group(1).strip()
    parts = listing.split()
    if len(parts) == 2 and parts[0].isdigit():
        num, name = parts
        return f"{name} {num}"
    if listing=="Bainbridge":
        return "Bainbridge 11143"
    if listing=="Longbranch":
        return "Longbranch 6821"
    if listing=="P3866":
            return "Poulsbo 3866"
    if listing=="P3956":
            return "Poulsbo 3956"
    if listing=="P563":
            return "Poulsbo 563"        
    else:
        return listing

def infer_service_type(text: str):
    """Determine whether invoice contains hot tub service."""
    if re.search(r"hot\s*tub", text, flags=re.IGNORECASE):
        return "Cleaning_Hottub"
    return "Cleaning"


def extract_invoice_number(pdf_path: Path):
    """
    Extract invoice number from filename.
    Example: 'INV065.pdf' → 'INV065'
    """
    name = pdf_path.stem  # 'INV065'
    m = re.search(r"INV\d+", name, flags=re.IGNORECASE)
    return m.group(0).upper() if m else None


def summarize_invoice(pdf_path: Path) -> dict:
    """Parse invoice PDF and return structured summary."""
    with pdfplumber.open(pdf_path) as pdf:
        pages_text = [page.extract_text() or "" for page in pdf.pages]

    text = "\n".join(pages_text)

    # First non-empty line is service provider name
    lines = [ln.strip() for ln in text.splitlines() if ln.strip()]
    service_provider = lines[0] if lines else "UnknownProvider"
    service_provider = np.where("camila" in service_provider.lower(), "Camila", service_provider)

    invoice_number = extract_invoice_number(pdf_path)
    total_amount = extract_total(text)
    listing = extract_listing(text)
    date_of_service = pd.to_datetime(extract_service_date(text)) if extract_service_date(text) else date.today()
    service_type = infer_service_type(text)

    invoicecontent = f"{date_of_service.month}.{date_of_service.day:02d}_{service_type}"

    # Build standard output filename
    today_str = date.today().strftime("%Y%m%d")
    amount_str = f"{total_amount:.2f}".rstrip("0").rstrip(".") if total_amount else "NA"

    filename = (
        f"{today_str}_{listing}_{service_provider}_{invoice_number}_"
        f"{invoicecontent}_{amount_str}"
    )

    return {
        "Date":today_str,
        "invoice_number": invoice_number,
        "total_amount": total_amount,
        "listing": listing,
        "date_of_service": date_of_service,
        "service_type": service_type,
        "payto": service_provider,
        "invoicecontent": invoicecontent,
        "filename": filename,
        "source_file": pdf_path.name,
    }

# %%
INPUT_DIR = Path("/Users/ylin/Downloads/Invoice/")  # <-- EDIT THIS
OUTPUT_FILE = "/Users/ylin/Downloads/Invoice/service_summary.xlsx"
Mapping = pd.read_excel("/Users/ylin/Google Drive/My Drive/Data and Reporting/04-Accounting/InvoicePayment/InvoiceTracking.xlsx",sheet_name='Mapping')

# %%
rows = []

for path in INPUT_DIR.rglob("*"):
    if not path.is_file():
        continue

    if path.suffix.lower() != ".pdf":
        # Skip non-PDFs
        continue

    row = summarize_invoice(path)
    if row:
        row["source_file"] = path.name
        rows.append(row)

df = pd.DataFrame(
        rows,
        columns=[
            "Date",
            "payto",
            "invoice_number",
            "total_amount", 
            "listing",
            "invoicecontent",
            "source_file",
            "filename"
        ],
    )
df = df.sort_values(by=["invoice_number"])

# %%
df = df.loc[df['payto']=="Camila"]
# Add JE contents
df["service_provider"] = 'Camila'
df["Category"] ='Cleaning Payout'
total_amount = sum(df["total_amount"])
df["JE Amount"] = total_amount 
first_inv = df["invoice_number"].iloc[0]
last_inv = df["invoice_number"].iloc[-1]
today_str = date.today().strftime("%Y%m%d")
df["Zelle content"] = f"{today_str}_Camila_Cleaning Payout_{first_inv}-{last_inv}_{total_amount:.2f}"
df["filename"] = df["filename"]+"_"+str(total_amount)
print(df)
df.to_excel(OUTPUT_FILE, index=False)
# Out:
#        Date   payto invoice_number  total_amount           listing  \
# 6  20260918  Camila         INV358         150.0       Poulsbo 563
# 4  20260918  Camila         INV359         200.0  Bainbridge 11143
# 0  20260918  Camila         INV360         205.0      Poulsbo 3956
# 1  20260918  Camila         INV361         200.0  Bainbridge 11143
# 3  20260918  Camila         INV362         205.0      Poulsbo 3956
# 2  20260918  Camila         INV363         150.0       Poulsbo 563
#
#          invoicecontent source_file  \
# 6         9.13_Cleaning  INV358.pdf
# 4         9.14_Cleaning  INV359.pdf
# 0  9.14_Cleaning_Hottub  INV360.pdf
# 1         9.17_Cleaning  INV361.pdf
# 3  9.18_Cleaning_Hottub  INV362.pdf
# 2         9.18_Cleaning  INV363.pdf
#
#                                             filename service_provider  \
# 6  20260918_Poulsbo 563_Camila_INV358_9.13_Cleani...           Camila
# 4  20260918_Bainbridge 11143_Camila_INV359_9.14_C...           Camila
# 0  20260918_Poulsbo 3956_Camila_INV360_9.14_Clean...           Camila
# 1  20260918_Bainbridge 11143_Camila_INV361_9.17_C...           Camila
# 3  20260918_Poulsbo 3956_Camila_INV362_9.18_Clean...           Camila
# 2  20260918_Poulsbo 563_Camila_INV363_9.18_Cleani...           Camila
#
#           Category  JE Amount  \
# 6  Cleaning Payout     1110.0
# 4  Cleaning Payout     1110.0
# 0  Cleaning Payout     1110.0
# 1  Cleaning Payout     1110.0
# 3  Cleaning Payout     1110.0
# 2  Cleaning Payout     1110.0
#
#                                        Zelle content
# 6  20260918_Camila_Cleaning Payout_INV358-INV363_...
# 4  20260918_Camila_Cleaning Payout_INV358-INV363_...
# 0  20260918_Camila_Cleaning Payout_INV358-INV363_...
# 1  20260918_Camila_Cleaning Payout_INV358-INV363_...
# 3  20260918_Camila_Cleaning Payout_INV358-INV363_...
# 2  20260918_Camila_Cleaning Payout_INV358-INV363_...

# %%
# change filenames for Camila invoices
for _, row in df.iterrows():
    old_path = INPUT_DIR / row["source_file"]
    new_name = row["filename"] + ".pdf"
    new_path = old_path.with_name(new_name)

    if old_path.exists():
        print(f"Renaming: {old_path.name} → {new_name}")
        old_path.rename(new_path)
    else:
        print(f"File not found: {old_path}")
# Out:
# Renaming: INV358.pdf → 20260918_Poulsbo 563_Camila_INV358_9.13_Cleaning_150_1110.0.pdf
# Renaming: INV359.pdf → 20260918_Bainbridge 11143_Camila_INV359_9.14_Cleaning_200_1110.0.pdf
# Renaming: INV360.pdf → 20260918_Poulsbo 3956_Camila_INV360_9.14_Cleaning_Hottub_205_1110.0.pdf
# Renaming: INV361.pdf → 20260918_Bainbridge 11143_Camila_INV361_9.17_Cleaning_200_1110.0.pdf
# Renaming: INV362.pdf → 20260918_Poulsbo 3956_Camila_INV362_9.18_Cleaning_Hottub_205_1110.0.pdf
# Renaming: INV363.pdf → 20260918_Poulsbo 563_Camila_INV363_9.18_Cleaning_150_1110.0.pdf

# %%
# change names based on excel sheet
df = pd.read_excel("/Users/ylin/Google Drive/My Drive/Data and Reporting/04-Accounting/InvoicePayment/InvoiceTracking.xlsx")
df = df.loc[df["Date"]=='2026-08-30']
for _, row in df.iterrows():
    old_path = INPUT_DIR / row["fileName"]
    name_ext =row["fileName"].split(".")[-1]
    new_name = f"{row['filename']}.{name_ext}"
    new_path = old_path.with_name(new_name)
    if not old_path.exists():
        print(f"Skipping (not found): {old_path}")
        continue

    print(f"Renaming: {old_path.name} → {new_name}")
    old_path.rename(new_path)
# Out:
# Renaming: Order details - Walmart.com 4910.pdf → 20260830_OSBR_Walmart_2000148-75224910_7.23_Laundry supplies_123.28.pdf
# Renaming: Order details - Walmart.com 6643.pdf → 20260830_OSBR_Walmart_2000149-93726643_7.26_hand soap_38.63.pdf
# Renaming: Order details - Walmart.com 8835.pdf → 20260830_OSBR_Walmart_2000149-69578835_8.1_bath towel_61.45.pdf
# Renaming: Order details - Walmart.com 7142 in store.pdf → 20260830_OSBR_Walmart_TC# 9393191511287435 7142_8.11_water coff cream candy_59.49.pdf
# Renaming: Order details - Walmart.com 0191.pdf → 20260830_OSBR_Walmart_2000151-13620191_8.12_Bath Towel_92.92.pdf
# Renaming: Order details - Walmart.com 5108.pdf → 20260830_OSBR_Walmart_2000149-37835108_8.14_mattress topper sheets_164.68.pdf
# Renaming: Order details - Walmart.com 3109.pdf → 20260830_OSBR_Walmart_2000150-28963109_8.15_supplies_281.85.pdf
# Renaming: Order details - Walmart.com 6246.pdf → 20260830_OSBR_Walmart_2000149-60356246_8.17_trash bags paint brushes_36.66.pdf
# Renaming: Order details - Walmart.com 7371.pdf → 20260830_OSBR_Walmart_2000152-31237371_8.19_dihscloth_104.69.pdf
# Renaming: Order details - Walmart.com 7141.pdf → 20260830_OSBR_Walmart_2000153-60497141_8.20_sponge holder_190.28.pdf
# Renaming: Order details - Walmart.com 4732.pdf → 20260830_OSBR_Walmart_2000152-97074732_8.21_Mop coffee maker bulds_98.83.pdf
# Renaming: Order details - Walmart.com 9937.pdf → 20260830_OSBR_Walmart_2000151-02729937_8.23_organizers Mop water handsoap_91.71.pdf
# Renaming: Order details - Walmart.com 9213.pdf → 20260830_OSBR_Walmart_2000152-18549213_8.26_seasoning_143.22.pdf
